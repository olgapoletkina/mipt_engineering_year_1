# %% [markdown]
# ![data_loaded.png](attachment:data_loaded.png)

# %% [markdown]
# # Dashboard link
#
#
# https://datalens.yandex.cloud/08wum524021cm-oiga-dashboard

# %% [markdown]
# |LEFT([timestamp], 16)|190121846|1574694804|5688788675|
# |:-|:-:|:-:|-:|
# |2025-04-05|9| |2|
# |2025-04-06|1|3| |
# |2025-04-07|8| | |
# |2025-04-08|5| | |

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# |Category|countd([action])|
# |:-|-:|
# |message: message|17|
# |/start: /start|7|
# |/help: /help|4|

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# |user_id|action|count([action])|
# |:-|:-:|-:|
# |190121846|/help|4|
# |190121846|/start|5|
# |190121846|message|14|
# |1574694804|/start|1|
# |1574694804|message|2|
# |5688788675|/start|1|
# |5688788675|message|1|

# %% [markdown]
# ![image.png](attachment:image.png)
